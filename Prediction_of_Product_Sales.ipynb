# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedshehada/Prediction-of-Product-Sales/blob/main/Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction of Product Sales
# - Author: Mohammed Shehada

# %% [markdown]
# [link text](https://)## Project Overview

# %% [markdown]
# ## Load and Inspect Data

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Feature Inspection
